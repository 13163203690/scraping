# %% [markdown]
# ### 豆瓣电影爬虫

# %%
import requests
from lxml import etree
 

headers={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
    'referer': 'https://movie.douban.com/'
}

#这里加上cookie才能进行正常访问，还有说明一点这里的cookie是进入职位详情之后的cookie
 
response=requests.get("https://movie.douban.com/cinema/nowplaying/zhoukou/",headers=headers)
text=response.text
#print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" class="ua-windows ua-webkit">
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#     <meta name="renderer" content="webkit">
#     <meta name="referrer" content="always">
#     <meta name="google-site-verification" content="ok0wCgT20tBBgo9_zat2iAcimtN4Ftf5ccsh092Xeyw" />
#     <title>
#     周口 - 在线购票&amp;影讯
# </title>
#
#     <meta name="baidu-site-verification" content="cZdR4xxR7RxmM4zE" />
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#
#     <meta name="keywords" content="周口,在线购票,网上电影票预订,优惠电影票,影讯,排片,放映时间,电影票价"/>
#     <meta name="description" content="周口电影院在线优惠购票及影讯排片查询"/>
#
#     <link rel="apple-touch-icon" href="/pics/movie/apple-touch-icon.png">
#     <link href="https://img3.doubanio.com/f/shire/859dba5cddc7ed1435808cf5a8ddde5792cd6e0c/css/douban.css" rel="stylesheet" type="text/css">
# ...

# %%
html = etree.HTML(text)
ul= html.xpath('//ul[@class="lists"]')[0]
lis =ul.xpath('./li')
positions=[]
for li in lis:
    title=li.xpath('@data-title')[0]
    score=li.xpath('@data-score')[0]
    star=li.xpath('@data-star')[0]
    duration=li.xpath('@data-duration')[0]
    director=li.xpath('@data-director')[0]
    actors=li.xpath('@data-actors')[0]
    img=li.xpath('.//img/@src')[0]
    #print(img)
    position={
        'title':title,
        'score':score,
        'star':star,
        'duration':duration,
        'director':director,
        'actors':actors,
        'img':img  
    }
    
    positions.append(position)
print(positions)
# Out:
# [{'title': '唐人街探案3', 'score': '5.9', 'star': '30', 'duration': '136分钟', 'director': '陈思诚', 'actors': '王宝强 / 刘昊然 / 妻夫木聪', 'img': 'https://img2.doubanio.com/view/photo/s_ratio_poster/public/p2622388983.jpg'}, {'title': '你好，李焕英', 'score': '8.3', 'star': '45', 'duration': '128分钟', 'director': '贾玲', 'actors': '贾玲 / 张小斐 / 沈腾', 'img': 'https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2629056068.jpg'}, {'title': '刺杀小说家', 'score': '7.1', 'star': '35', 'duration': '130分钟', 'director': '路阳', 'actors': '雷佳音 / 杨幂 / 董子健', 'img': 'https://img9.doubanio.com/view/photo/s_ratio_poster/public/p2628440875.jpg'}, {'title': '人潮汹涌', 'score': '7.3', 'star': '40', 'duration': '119分钟', 'director': '饶晓志', 'actors': '刘德华 / 肖央 / 万茜', 'img': 'https://img1.doubanio.com/view/photo/s_ratio_poster/public/p2632863458.jpg'}, {'title': '侍神令', 'score': '6.1', 'star': '30', 'duration': '120分钟', 'director': '李蔚然', 'actors': '陈坤 / 周迅 / 陈伟霆', 'img': 'https://img2.doubanio.com/view/photo/s_ratio_poster/public/p2629
# ...

# %%
for a in aList:
     #print(etree.tostring(a,encoding='utf-8').decode('utf-8'))
    #print ("https://careers.tencent.com/jobdesc.html?postId="+a)#

#     
#     positions.append(position)
# print(positions)
