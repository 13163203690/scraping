# %% [markdown]
# ## python 爬虫案例
# 拉勾网存在反爬虫机制

# %%
from urllib import request
 
resp=request.urlopen('https://www.lagou.com/jobs/positionAjax.json?city=%E6%9D%AD%E5%B7%9E&needAddtionalResult=false')
print(resp.read())
# Out:
# b'{"status":false,"msg":"\xe6\x82\xa8\xe6\x93\x8d\xe4\xbd\x9c\xe5\xa4\xaa\xe9\xa2\x91\xe7\xb9\x81,\xe8\xaf\xb7\xe7\xa8\x8d\xe5\x90\x8e\xe5\x86\x8d\xe8\xae\xbf\xe9\x97\xae","clientIp":"123.13.60.113","state":2408}\n'

# %% [markdown]
# 加入请求头如下

# %%
from urllib import request,parse
 
url='https://www.lagou.com//jobs/positionAjax.json?needAddtionalResult=false'
headers = {
    'Accept':'application/json, text/javascript, */*; q=0.01',
    'Referer':'https://www.lagou.com/jobs/list_python?labelWords=sug&fromSearch=true&suginput=py',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36',
    'Cookie':'JSESSIONID=ABAAABAABAGABFA5063567BC9EF8020592E27E00E24AE22; WEBTJ-ID=20210213%E4%B8%8A%E5%8D%889:45:37094537-177991098617c3-047353a2763ed5-53e3566-1044480-177991098628df; RECOMMEND_TIP=true; user_trace_token=20210213094538-60119109-267f-438e-a8a9-c8b21e179f14; LGUID=20210213094538-3ec3951e-365a-4a8b-bbd5-471dce37db10; _ga=GA1.2.1158281158.1613180738; Hm_lvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1613180738; sajssdk_2015_cross_new_user=1; sensorsdata2015session=%7B%7D; _gid=GA1.2.663168367.1613180738; index_location_city=%E5%85%A8%E5%9B%BD; TG-TRACK-CODE=index_hotjob; __lg_stoken__=cfa9cc98252f1bace1e1fc132c29c52abd1160dabf4fd6d08ae920b8e4f6eefe3071bdd7f09b1439831e08913cb2596f883f014c20d447297cd0783673a9d6cc61e0e594bfac; X_MIDDLE_TOKEN=78f8452d257dc8ab799a298b676e1593; X_HTTP_TOKEN=cdc8bf8b266d734d5151813161edc1f4b513753ed3; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2217799109a5729b-0505bf6cadcdb7-53e3566-1044480-17799109a5893a%22%2C%22first_id%22%3A%22%22%2C%22props%22%3A%7B%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%2C%22%24latest_referrer%22%3A%22%22%2C%22%24os%22%3A%22Windows%22%2C%22%24browser%22%3A%22Chrome%22%2C%22%24browser_version%22%3A%2288.0.4324.150%22%7D%2C%22%24device_id%22%3A%2217799109a5729b-0505bf6cadcdb7-53e3566-1044480-17799109a5893a%22%7D; Hm_lpvt_4233e74dff0ae5bd0a3d81c6ccf756e6=1613181515; LGRID=20210213095913-1eb2e316-4df1-4f62-ba38-3f57e0a86ad5; SEARCH_ID=6657350c21c64eec8eb4da89ad77a446'
}
data={
    'first':"true",
    'pn':1,
    'kd':"python"
}
 
req = request.Request(url,headers=headers,data=parse.urlencode(data).encode('utf-8'),method='POST')
resp = request.urlopen(req)
print(resp.read().decode('utf-8'))
# Out:
# {"success":true,"msg":null,"code":0,"content":{"showId":"ecfe62f7362f4c6d94b1b03036dc95c0","hrInfoMap":{"7033995":{"userId":14610302,"portrait":"i/image2/M01/0E/AC/CgotOVyhgdWACcZgAABtgMsGk64396.png","realName":"陈小路","positionName":"HR","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"8267516":{"userId":14699388,"portrait":"i/image/M00/6E/D8/CgqCHl-zltGATWTiAABq7l7a11A073.png","realName":"梁先生","positionName":"HR人事专员","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"8066937":{"userId":366796,"portrait":"i/image2/M01/78/5B/CgotOVtqiYaASnsGAAAJ6xgePlE450.png","realName":"Klook","positionName":"HR","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"7985692":{"userId":19459507,"portrait":"i/image/M00/71/08/CgqCHl-8v3-AYuc6AABWgwBq6QY726.jpg","realName":"冯倚婷","positionName":"招聘专员","phone":null,"receiveEmail":null,"userLevel":"G1","canTalk":true},"8137370":{"userId":20265733,"portrait":"i/image2/M01/0E/AC/CgotOVyhgcmAaD2nAABq7l7a11A980.png
# ...

# %% [markdown]
# ### 使用代理

# %%
from urllib import request
 
#没有使用代理
url = 'http://httpbin.org/ip'
resp=request.urlopen(url)
print(resp.read())
# Out:
# b'{\n  "origin": "115.63.101.234"\n}\n'

# %%
from urllib import request
 
#使用代理
#1.使用proxyhandler，传入代理构建一个handler
#2.使用上面创建的handler创建一个oprner
#3.使用opener发送一个请求
url = 'http://httpbin.org/ip'
handler=request.ProxyHandler({"http":"58.253.159.68:9999"})
opener=request.build_opener(handler)
resp=opener.open(url)
print(resp.read())
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# F:\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# F:\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# F:\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ...
